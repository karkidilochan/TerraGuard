# %%
prompts = ["CHAIN_OF_THOUGHT", "ZERO_SHOT", "FEW_SHOT", "RAG"]
temperatures = [0.1,0.7]

output_data = []
for prompt in prompts:
    for temperature in temperatures:
        file_name = f"./../benchmarking_results/mistral-large-latest_{temperature}_PromptingStrategy.{prompt}.json"
        print(file_name)

        import json
        from collections import defaultdict
        import re

        # Load the JSON data
        try:
            with open(file_name, "r") as f:
                data = json.load(f)
        except FileNotFoundError:
            print(f"File not found: {file_name}. Skipping...")
            continue

        # Initialize stats dictionary
        stats = defaultdict(lambda: {"syntax_valid_count": 0, "total": 0, "pass_rate_sum": 0.0})

        # Helper to extract pass rate
        def extract_pass_rate(report):
            match = re.search(r"Pass Rate: ([0-9.]+)%", report)
            return float(match.group(1)) if match else 0.0

        # Process each entry
        for item in data:
            difficulty = item.get("Difficulty", "unknown")
            syntax_valid = item.get("Validation Summary", {}).get("syntax_valid", False)
            compliance_report = item.get("Compliance Report", "")

            stats[difficulty]["total"] += 1
            if syntax_valid:
                stats[difficulty]["syntax_valid_count"] += 1
            stats[difficulty]["pass_rate_sum"] += extract_pass_rate(compliance_report)

        # Print results
        temp = []
        for difficulty, values in sorted(stats.items()):
            total = values["total"]
            syntax_count = values["syntax_valid_count"]
            avg_pass_rate = values["pass_rate_sum"] / total if total else 0
            temp.append({
                "Difficulty": difficulty,
                "Syntax Valid Count": f"{syntax_count/total:.2f}%",
                "Avg Pass Rate": f"{avg_pass_rate:.2f}%"
            })
        output_data.append({
            "Prompt": prompt,
            "Temperature": temperature,
            "Results": temp
        })

output_file = f"summary_mistral_remaining.json"
with open(output_file, "w") as json_file:
    json.dump(output_data, json_file, indent=4)
# Out:
# ./../benchmarking_results/mistral-large-latest_0.1_PromptingStrategy.CHAIN_OF_THOUGHT.json
# File not found: ./../benchmarking_results/mistral-large-latest_0.1_PromptingStrategy.CHAIN_OF_THOUGHT.json. Skipping...
# ./../benchmarking_results/mistral-large-latest_0.7_PromptingStrategy.CHAIN_OF_THOUGHT.json
# File not found: ./../benchmarking_results/mistral-large-latest_0.7_PromptingStrategy.CHAIN_OF_THOUGHT.json. Skipping...
# ./../benchmarking_results/mistral-large-latest_0.1_PromptingStrategy.ZERO_SHOT.json
# ./../benchmarking_results/mistral-large-latest_0.7_PromptingStrategy.ZERO_SHOT.json
# File not found: ./../benchmarking_results/mistral-large-latest_0.7_PromptingStrategy.ZERO_SHOT.json. Skipping...
# ./../benchmarking_results/mistral-large-latest_0.1_PromptingStrategy.FEW_SHOT.json
# ./../benchmarking_results/mistral-large-latest_0.7_PromptingStrategy.FEW_SHOT.json
# File not found: ./../benchmarking_results/mistral-large-latest_0.7_PromptingStrategy.FEW_SHOT.json. Skipping...
# ./../benchmarking_results/mistral-large-latest_0.1_PromptingStrategy.RAG.json
# File not found: ./../benchmarking_results/mistral-large-latest_0.1_PromptingStrategy.RAG.json. Skipping...
# ./../benchmarking_results/mistral-large-latest_0.7_PromptingStrategy.RAG.json
# File not found: ./../benchmarking_results/mistral-large-latest_0.7_PromptingStrategy.RAG.json. Skipping...

# %%
import json

with open('./../aws_resources.json', 'r') as file:
    aws_resources = json.load(file)

with open('./../aws_data_sources.json', 'r') as file:
    aws_data_sources = json.load(file)


print(len(aws_resources))
# Out:
# 1000

# %%
aws_resource_names = set()
aws_subcategories = set()
for resource in aws_resources:
    aws_resource_names.add(resource['resource_name'])
    aws_subcategories.add(resource['metadata']['subcategory'])

for source in aws_data_sources:
    aws_resource_names.add(source['resource_name'])
    aws_subcategories.add(source['metadata']['subcategory'])

# %%
len(aws_subcategories)
# Out:
# 214

# %%
# Write aws_resource_names to a txt file
# with open("aws_resource_names.txt", "w") as file:
#     for name in aws_resource_names:
#         file.write(f"{name}\n")


# Write aws_subcategories to a txt file
with open("aws_subcategories.txt", "w") as file:
    for subcategory in aws_subcategories:
        file.write(f"{subcategory},")

# %%
aws_subcategories
# Out:
# ['IAM Access Analyzer',
#  'IAM Access Analyzer',
#  'Account Management',
#  'Account Management',
#  'Account Management',
#  'ACM (Certificate Manager)',
#  'ACM (Certificate Manager)',
#  'ACM PCA (Certificate Manager Private Certificate Authority)',
#  'ACM PCA (Certificate Manager Private Certificate Authority)',
#  'ACM PCA (Certificate Manager Private Certificate Authority)',
#  'ACM PCA (Certificate Manager Private Certificate Authority)',
#  'ACM PCA (Certificate Manager Private Certificate Authority)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'Amplify',
#  'Amplify',
#  'Amplify',
#  'Amplify',
#  'Amplify',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'API Gateway V2',
#  'ELB Classic',
#  'Application Auto Scaling',
#  'Application Auto Scaling',
#  'Application Auto Scaling',
#  'AppConfig',
#  'AppConfig',
#  'AppConfig',
#  'AppConfig',
#  'AppConfig',
#  'AppConfig',
#  'AppConfig',
#  'AppConfig',
#  'AppFabric',
#  'AppFabric',
#  'AppFabric',
#  'AppFabric',
#  'AppFabric',
#  'AppFlow',
#  'AppFlow',
#  'AppIntegrations',
#  'AppIntegrations',
#  'CloudWatch Application Insights',
#  'App Mesh',
#  'App Mesh',
#  'App Mesh',
#  'App Mesh',
#  'App Mesh',
#  'App Mesh',
#  'App Mesh',
#  'App Runner',
#  'App Runner',
#  'App Runner',
#  'App Runner',
#  'App Runner',
#  'App Runner',
#  'App Runner',
#  'App Runner',
#  'App Runner',
#  'AppStream 2.0',
#  'AppStream 2.0',
#  'AppStream 2.0',
#  'AppStream 2.0',
#  'AppStream 2.0',
#  'AppStream 2.0',
#  'AppStream 2.0',
#  'AppSync',
#  'AppSync',
#  'AppSync',
#  'AppSync',
#  'AppSync',
#  'AppSync',
#  'AppSync',
#  'AppSync',
#  'AppSync',
#  'AppSync',
#  'Athena',
#  'Athena',
#  'Athena',
#  'Athena',
#  'Athena',
#  'Athena',
#  'Audit Manager',
#  'Audit Manager',
#  'Audit Manager',
#  'Audit Manager',
#  'Audit Manager',
#  'Audit Manager',
#  'Audit Manager',
#  'Audit Manager',
#  'Auto Scaling',
#  'Auto Scaling',
#  'Auto Scaling',
#  'Auto Scaling',
#  'Auto Scaling',
#  'Auto Scaling',
#  'Auto Scaling',
#  'Auto Scaling',
#  'Auto Scaling Plans',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Backup',
#  'Batch',
#  'Batch',
#  'Batch',
#  'Batch',
#  'BCM Data Exports',
#  'Bedrock',
#  'Bedrock',
#  'Bedrock',
#  'Bedrock',
#  'Bedrock',
#  'Bedrock',
#  'Bedrock Agents',
#  'Bedrock Agents',
#  'Bedrock Agents',
#  'Bedrock Agents',
#  'Bedrock Agents',
#  'Bedrock Agents',
#  'Bedrock Agents',
#  'Web Services Budgets',
#  'Web Services Budgets',
#  'CE (Cost Explorer)',
#  'CE (Cost Explorer)',
#  'CE (Cost Explorer)',
#  'CE (Cost Explorer)',
#  'Chatbot',
#  'Chatbot',
#  'Chime',
#  'Chime',
#  'Chime',
#  'Chime',
#  'Chime',
#  'Chime',
#  'Chime',
#  'Chime SDK Media Pipelines',
#  'Chime SDK Voice',
#  'Chime SDK Voice',
#  'Chime SDK Voice',
#  'Chime SDK Voice',
#  'Clean Rooms',
#  'Clean Rooms',
#  'Clean Rooms',
#  'Cloud9',
#  'Cloud9',
#  'Cloud Control API',
#  'CloudFormation',
#  'CloudFormation',
#  'CloudFormation',
#  'CloudFormation',
#  'CloudFormation',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront',
#  'CloudFront KeyValueStore',
#  'CloudHSM',
#  'CloudHSM',
#  'CloudSearch',
#  'CloudSearch',
#  'CloudTrail',
#  'CloudTrail',
#  'CloudTrail',
#  'CloudWatch',
#  'CloudWatch',
#  'CloudWatch',
#  'CloudWatch',
#  'EventBridge',
#  'EventBridge',
#  'EventBridge',
#  'EventBridge',
#  'EventBridge',
#  'EventBridge',
#  'EventBridge',
#  'EventBridge',
#  'EventBridge',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch Logs',
#  'CloudWatch',
#  'CloudWatch',
#  'CloudWatch Logs',
#  'CodeArtifact',
#  'CodeArtifact',
#  'CodeArtifact',
#  'CodeArtifact',
#  'CodeBuild',
#  'CodeBuild',
#  'CodeBuild',
#  'CodeBuild',
#  'CodeBuild',
#  'CodeBuild',
#  'CodeCatalyst',
#  'CodeCatalyst',
#  'CodeCatalyst',
#  'CodeCommit',
#  'CodeCommit',
#  'CodeCommit',
#  'CodeCommit',
#  'CodeConnections',
#  'CodeConnections',
#  'CodeDeploy',
#  'CodeDeploy',
#  'CodeDeploy',
#  'CodeGuru Profiler',
#  'CodeGuru Reviewer',
#  'CodePipeline',
#  'CodePipeline',
#  'CodePipeline',
#  'CodeStar Connections',
#  'CodeStar Connections',
#  'CodeStar Notifications',
#  'Cognito Identity',
#  'Cognito Identity',
#  'Cognito Identity',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Cognito IDP (Identity Provider)',
#  'Comprehend',
#  'Comprehend',
#  'Compute Optimizer',
#  'Compute Optimizer',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Config',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Connect',
#  'Control Tower',
#  'Control Tower',
#  'Cost Optimization Hub',
#  'Cost Optimization Hub',
#  'Cost and Usage Report',
#  'VPN (Site-to-Site)',
#  'Connect Customer Profiles',
#  'Connect Customer Profiles',
#  'Data Exchange',
#  'Data Exchange',
#  'Data Exchange',
#  'Data Pipeline',
#  'Data Pipeline',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataSync',
#  'DataZone',
#  'DataZone',
#  'DataZone',
#  'DataZone',
#  'DataZone',
#  'DataZone',
#  'DataZone',
#  'DataZone',
#  'DataZone',
#  'DataZone',
#  'DynamoDB Accelerator (DAX)',
#  'DynamoDB Accelerator (DAX)',
#  'DynamoDB Accelerator (DAX)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'RDS (Relational Database)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'Detective',
#  'Detective',
#  'Detective',
#  'Detective',
#  'Detective',
#  'Device Farm',
#  'Device Farm',
#  'Device Farm',
#  'Device Farm',
#  'Device Farm',
#  'Device Farm',
#  'DevOps Guru',
#  'DevOps Guru',
#  'DevOps Guru',
#  'DevOps Guru',
#  'Directory Service',
#  'Directory Service',
#  'Directory Service',
#  'Directory Service',
#  'Directory Service',
#  'Directory Service',
#  'Directory Service',
#  'Directory Service',
#  'DLM (Data Lifecycle Manager)',
#  'DMS (Database Migration)',
#  'DMS (Database Migration)',
#  'DMS (Database Migration)',
#  'DMS (Database Migration)',
#  'DMS (Database Migration)',
#  'DMS (Database Migration)',
#  'DMS (Database Migration)',
#  'DMS (Database Migration)',
#  'DocumentDB',
#  'DocumentDB',
#  'DocumentDB',
#  'DocumentDB',
#  'DocumentDB',
#  'DocumentDB',
#  'DocumentDB',
#  'DocumentDB Elastic',
#  'DRS (Elastic Disaster Recovery)',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'Direct Connect',
#  'DynamoDB',
#  'DynamoDB',
#  'DynamoDB',
#  'DynamoDB',
#  'DynamoDB',
#  'DynamoDB',
#  'DynamoDB',
#  'DynamoDB',
#  'DynamoDB',
#  'EBS (EC2)',
#  'EBS (EC2)',
#  'EBS (EC2)',
#  'EBS (EC2)',
#  'EBS (EC2)',
#  'EBS (EC2)',
#  'EBS (EC2)',
#  'EBS (EC2)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'Wavelength',
#  'VPN (Client)',
#  'VPN (Client)',
#  'VPN (Client)',
#  'VPN (Client)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'Outposts (EC2)',
#  'Outposts (EC2)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'Transit Gateway',
#  'ECR (Elastic Container Registry)',
#  'ECR (Elastic Container Registry)',
#  'ECR (Elastic Container Registry)',
#  'ECR (Elastic Container Registry)',
#  'ECR (Elastic Container Registry)',
#  'ECR (Elastic Container Registry)',
#  'ECR (Elastic Container Registry)',
#  'ECR (Elastic Container Registry)',
#  'ECR (Elastic Container Registry)',
#  'ECR Public',
#  'ECR Public',
#  'ECS (Elastic Container)',
#  'ECS (Elastic Container)',
#  'ECS (Elastic Container)',
#  'ECS (Elastic Container)',
#  'ECS (Elastic Container)',
#  'ECS (Elastic Container)',
#  'ECS (Elastic Container)',
#  'ECS (Elastic Container)',
#  'EFS (Elastic File System)',
#  'EFS (Elastic File System)',
#  'EFS (Elastic File System)',
#  'EFS (Elastic File System)',
#  'EFS (Elastic File System)',
#  'EFS (Elastic File System)',
#  'VPC (Virtual Private Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EC2 (Elastic Compute Cloud)',
#  'EKS (Elastic Kubernetes)',
#  'EKS (Elastic Kubernetes)',
#  'EKS (Elastic Kubernetes)',
#  'EKS (Elastic Kubernetes)',
#  'EKS (Elastic Kubernetes)',
#  'EKS (Elastic Kubernetes)',
#  'EKS (Elastic Kubernetes)',
#  'EKS (Elastic Kubernetes)',
#  'Elastic Beanstalk',
#  'Elastic Beanstalk',
#  'Elastic Beanstalk',
#  'Elastic Beanstalk',
#  'ElastiCache',
#  'ElastiCache',
#  'ElastiCache',
#  'ElastiCache',
#  'ElastiCache',
#  'ElastiCache',
#  'ElastiCache',
#  'ElastiCache',
#  'ElastiCache',
#  'ElastiCache',
#  'Elasticsearch',
#  'Elasticsearch',
#  'Elasticsearch',
#  'Elasticsearch',
#  'Elastic Transcoder',
#  'Elastic Transcoder',
#  'ELB Classic',
#  'ELB Classic',
#  'EMR',
#  'EMR',
#  'EMR',
#  'EMR',
#  'EMR',
#  'EMR',
#  'EMR',
#  'EMR',
#  'EMR Containers',
#  'EMR Containers',
#  'EMR Serverless',
#  'CloudWatch Evidently',
#  'CloudWatch Evidently',
#  'CloudWatch Evidently',
#  'CloudWatch Evidently',
#  'FinSpace',
#  'FinSpace',
#  'FinSpace',
#  'FinSpace',
#  'FinSpace',
#  'FinSpace',
#  'FinSpace',
#  'FIS (Fault Injection Simulator)',
#  'VPC (Virtual Private Cloud)',
#  'FMS (Firewall Manager)',
#  'FMS (Firewall Manager)',
#  'FMS (Firewall Manager)',
#  'FSx',
#  'FSx',
#  'FSx',
#  'FSx',
#  'FSx',
#  'FSx',
#  'FSx',
#  'FSx',
#  'FSx',
#  'FSx',
#  'FSx',
#  'GameLift',
#  'GameLift',
#  'GameLift',
#  'GameLift',
#  'GameLift',
#  'GameLift',
#  'S3 Glacier',
#  'S3 Glacier',
#  'Global Accelerator',
#  'Global Accelerator',
#  'Global Accelerator',
#  'Global Accelerator',
#  'Global Accelerator',
#  'Global Accelerator',
#  'Global Accelerator',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Glue',
#  'Managed Grafana',
#  'Managed Grafana',
#  'Managed Grafana',
#  'Managed Grafana',
#  'Managed Grafana',
#  'Managed Grafana',
#  'Managed Grafana',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'GuardDuty',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'IAM (Identity & Access Management)',
#  'SSO Identity Store',
#  'SSO Identity Store',
#  'SSO Identity Store',
#  'EC2 Image Builder',
#  'EC2 Image Builder',
#  'EC2 Image Builder',
#  'EC2 Image Builder',
#  'EC2 Image Builder',
#  'EC2 Image Builder',
#  'EC2 Image Builder',
#  'EC2 Image Builder',
#  'EC2 Image Builder',
#  'Inspector',
#  'Inspector',
#  'Inspector',
#  'Inspector',
#  'Inspector Classic',
#  'Inspector Classic',
#  'Inspector Classic',
#  'EC2 (Elastic Compute Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'CloudWatch Internet Monitor',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IoT Core',
#  'IVS (Interactive Video)',
#  'IVS (Interactive Video)',
#  'IVS (Interactive Video)',
#  'IVS (Interactive Video) Chat',
#  'IVS (Interactive Video) Chat',
#  'Kendra',
#  'Kendra',
#  'Kendra',
#  'Kendra',
#  'Kendra',
#  'Kendra',
#  'EC2 (Elastic Compute Cloud)',
#  'Keyspaces (for Apache Cassandra)',
#  'Keyspaces (for Apache Cassandra)',
#  'Kinesis Analytics',
#  'Kinesis Firehose',
#  'Kinesis',
#  'Kinesis',
#  'Kinesis',
#  'Kinesis Video',
#  'Kinesis Analytics V2',
#  'Kinesis Analytics V2',
#  'KMS (Key Management)',
#  'KMS (Key Management)',
#  'KMS (Key Management)',
#  'KMS (Key Management)',
#  'KMS (Key Management)',
#  'KMS (Key Management)',
#  'KMS (Key Management)',
#  'KMS (Key Management)',
#  'KMS (Key Management)',
#  'Lake Formation',
#  'Lake Formation',
#  'Lake Formation',
#  'Lake Formation',
#  'Lake Formation',
#  'Lake Formation',
#  'Lake Formation',
#  'Lake Formation',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Lambda',
#  'Auto Scaling',
#  'EC2 (Elastic Compute Cloud)',
#  'ELB (Elastic Load Balancing)',
#  'ELB Classic',
#  'ELB (Elastic Load Balancing)',
#  'ELB (Elastic Load Balancing)',
#  'ELB (Elastic Load Balancing)',
#  'ELB Classic',
#  'ELB (Elastic Load Balancing)',
#  'ELB (Elastic Load Balancing)',
#  'ELB (Elastic Load Balancing)',
#  'ELB (Elastic Load Balancing)',
#  'Lex Model Building',
#  'Lex Model Building',
#  'Lex Model Building',
#  'Lex Model Building',
#  'Lex V2 Models',
#  'Lex V2 Models',
#  'Lex V2 Models',
#  'Lex V2 Models',
#  'Lex V2 Models',
#  'Lex V2 Models',
#  'License Manager',
#  'License Manager',
#  'License Manager',
#  'License Manager',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'Lightsail',
#  'ELB Classic',
#  'ELB Classic',
#  'ELB Classic',
#  'Location',
#  'Location',
#  'Location',
#  'Location',
#  'Location',
#  'Location',
#  'Mainframe Modernization',
#  'Mainframe Modernization',
#  'Mainframe Modernization',
#  'Macie',
#  'Macie',
#  'Macie',
#  'Macie',
#  'Macie',
#  'Macie',
#  'Macie',
#  'Macie',
#  'Macie',
#  'VPC (Virtual Private Cloud)',
#  'Elemental MediaConvert',
#  'Elemental MediaPackage',
#  'Elemental MediaPackage Version 2',
#  'Elemental MediaStore',
#  'Elemental MediaStore',
#  'Elemental MediaLive',
#  'Elemental MediaLive',
#  'Elemental MediaLive',
#  'Elemental MediaLive',
#  'Elemental MediaLive',
#  'MemoryDB',
#  'MemoryDB',
#  'MemoryDB',
#  'MemoryDB',
#  'MemoryDB',
#  'MemoryDB',
#  'MemoryDB',
#  'MQ',
#  'MQ',
#  'Managed Streaming for Kafka',
#  'Managed Streaming for Kafka',
#  'Managed Streaming for Kafka',
#  'Managed Streaming for Kafka',
#  'Managed Streaming for Kafka',
#  'Managed Streaming for Kafka',
#  'Managed Streaming for Kafka',
#  'Managed Streaming for Kafka',
#  'Managed Streaming for Kafka Connect',
#  'Managed Streaming for Kafka Connect',
#  'Managed Streaming for Kafka Connect',
#  'MWAA (Managed Workflows for Apache Airflow)',
#  'VPC (Virtual Private Cloud)',
#  'Neptune',
#  'Neptune',
#  'Neptune',
#  'Neptune',
#  'Neptune',
#  'Neptune',
#  'Neptune',
#  'Neptune',
#  'Neptune',
#  'Neptune Analytics',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'VPC (Virtual Private Cloud)',
#  'Network Firewall',
#  'Network Firewall',
#  'Network Firewall',
#  'Network Firewall',
#  'Network Firewall',
#  'Network Firewall',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'Network Manager',
#  'CloudWatch Network Monitor',
#  'CloudWatch Network Monitor',
#  'CloudWatch Observability Access Manager',
#  'CloudWatch Observability Access Manager',
#  'CloudWatch Observability Access Manager',
#  'OpenSearch',
#  'OpenSearch',
#  'OpenSearch',
#  'OpenSearch',
#  'OpenSearch',
#  'OpenSearch',
#  'OpenSearch',
#  'OpenSearch',
#  'OpenSearch',
#  'OpenSearch Serverless',
#  'OpenSearch Serverless',
#  'OpenSearch Serverless',
#  'OpenSearch Serverless',
#  'OpenSearch Serverless',
#  'OpenSearch Serverless',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'OpsWorks',
#  'Organizations',
#  'Organizations',
#  'Organizations',
#  'Organizations',
#  'Organizations',
#  'Organizations',
#  'Organizations',
#  'OpenSearch Ingestion',
#  'Payment Cryptography Control Plane',
#  'Payment Cryptography Control Plane',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'Pinpoint',
#  'End User Messaging SMS',
#  'End User Messaging SMS',
#  'End User Messaging SMS']

# %% [markdown]
# Load Documents

# %%
import bs4
from langchain_community.document_loaders import WebBaseLoader


bs4_strainer = bs4.SoupStrainer(class_=('post-title',"post-header", "post-content"))

loader = WebBaseLoader(web_paths = ("https://lilianweng.github.io/posts/2023-06-23-agent/",), bs_kwargs = {"parse_only": bs4_strainer})

docs = loader.load()

assert len(docs) == 1
print(len(docs[0].page_content))
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# 43130

# %% [markdown]
# Splitting Documents

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 1000,
    chunk_overlap = 200,
    add_start_index = True,
)

all_splits = text_splitter.split_documents(docs)

print(len(all_splits))
# Out:
# 66

# %% [markdown]
# Storing Documents

# %%
import getpass
import os

if not os.environ.get("MISTRAL_API_KEY"):
  os.environ["MISTRAL_API_KEY"] = getpass.getpass("Enter API key for MistralAI: ")

from langchain_mistralai import MistralAIEmbeddings

embeddings = MistralAIEmbeddings(model="mistral-embed")

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("mistral-large-latest", model_provider="mistralai")

from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

# %%
document_ids = vector_store.add_documents(documents=all_splits)
print(document_ids)
# Out:
# An error occurred with MistralAI: Illegal header value b'Bearer '
# ---------------------------------------------------------------------------
# LocalProtocolError                        Traceback (most recent call last)
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpcore/_sync/http11.py:86, in HTTP11Connection.handle_request(self, request)
#      83 with Trace(
#      84     "send_request_headers", logger, request, kwargs
#      85 ) as trace:
# ---> 86     self._send_request_headers(**kwargs)
#      87 with Trace("send_request_body", logger, request, kwargs) as trace:
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpcore/_sync/http11.py:145, in HTTP11Connection._send_request_headers(self, request)
#     144 with map_exceptions({h11.LocalProtocolError: LocalProtocolError}):
# --> 145     event = h11.Request(
#     146         method=request.method,
#     147         target=request.url.target,
#     148         headers=request.headers,
#     149     )
#     150 self._send_event(event, timeout=timeout)
#
# File ~/anaconda3/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# LocalProtocolError: Illegal header value b'Bearer '
#
# The above exception was the direct cause of the following exception:
#
# LocalProtocolError                        Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 document_ids = vector_store.add_documents(documents=all_splits)
#       2 print(document_ids)
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/langchain_core/vectorstores/in_memory.py:187, in InMemoryVectorStore.add_documents(self, documents, ids, **kwargs)
#     185 """Add documents to the store."""
#     186 texts = [doc.page_content for doc in documents]
# --> 187 vectors = self.embedding.embed_documents(texts)
#     189 if ids and len(ids) != len(texts):
#     190     msg = (
#     191         f"ids must be the same length as texts. "
#     192         f"Got {len(ids)} ids and {len(texts)} texts."
#     193     )
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/langchain_mistralai/embeddings.py:245, in MistralAIEmbeddings.embed_documents(self, texts)
#     242         return response
#     244     for batch in self._get_batches(texts):
# --> 245         batch_responses.append(_embed_batch(batch))
#     246     return [
#     247         list(map(float, embedding_obj["embedding"]))
#     248         for response in batch_responses
#     249         for embedding_obj in response.json()["data"]
#     250     ]
#     251 except Exception as e:
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/tenacity/__init__.py:336, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     334 copy = self.copy()
#     335 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336 return copy(f, *args, **kw)
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/tenacity/__init__.py:398, in BaseRetrying._post_retry_check_actions.<locals>.<lambda>(rs)
#     396 def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397     if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398         self._add_action_func(lambda rs: rs.outcome.result())
#     399         return
#     401     if self.after is not None:
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~/anaconda3/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/langchain_mistralai/embeddings.py:234, in MistralAIEmbeddings.embed_documents.<locals>._embed_batch(batch)
#     226 @retry(
#     227     retry=retry_if_exception_type(
#     228         (httpx.TimeoutException, httpx.HTTPStatusError)
#    (...)
#     232 )
#     233 def _embed_batch(batch: List[str]) -> Response:
# --> 234     response = self.client.post(
#     235         url="/embeddings",
#     236         json=dict(
#     237             model=self.model,
#     238             input=batch,
#     239         ),
#     240     )
#     241     response.raise_for_status()
#     242     return response
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_client.py:1144, in Client.post(self, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1123 def post(
#    1124     self,
#    1125     url: URL | str,
#    (...)
#    1137     extensions: RequestExtensions | None = None,
#    1138 ) -> Response:
#    1139     """
#    1140     Send a `POST` request.
#    1141
#    1142     **Parameters**: See `httpx.request`.
#    1143     """
# -> 1144     return self.request(
#    1145         "POST",
#    1146         url,
#    1147         content=content,
#    1148         data=data,
#    1149         files=files,
#    1150         json=json,
#    1151         params=params,
#    1152         headers=headers,
#    1153         cookies=cookies,
#    1154         auth=auth,
#    1155         follow_redirects=follow_redirects,
#    1156         timeout=timeout,
#    1157         extensions=extensions,
#    1158     )
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)
#     823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File ~/anaconda3/lib/python3.9/contextlib.py:137, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     135     value = typ()
#     136 try:
# --> 137     self.gen.throw(typ, value, traceback)
#     138 except StopIteration as exc:
#     139     # Suppress StopIteration *unless* it's the same exception that
#     140     # was passed to throw().  This prevents a StopIteration
#     141     # raised inside the "with" statement from being suppressed.
#     142     return exc is not value
#
# File ~/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# LocalProtocolError: Illegal header value b'Bearer '

# %% [markdown]
# Retrieval and Generation

# %%
from langchain import hub

prompt = hub.pull("rlm/rag-prompt")

example_message =  prompt.invoke({
    "context": "(context goes here)",
    "question": "(question goes here)",
}).to_messages()

print(example_message)
# Out:
# [HumanMessage(content="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: (question goes here) \nContext: (context goes here) \nAnswer:", additional_kwargs={}, response_metadata={})]
# /home/dilochan/Documents/projects/terraguard/.venv/lib/python3.9/site-packages/langsmith/client.py:253: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(

# %%
question = "what is self reflection?"

retrieved_docs = vector_store.similarity_search(question)
docs_content = "\n\n".join(doc.page_content for doc in retrieved_docs)
print(docs_content)
answer = llm.invoke(prompt.invoke({"question": question, "context": docs_content}))
answer.content
# Out:
# Fig. 3. Illustration of the Reflexion framework. (Image source: Shinn & Labash, 2023)
# The heuristic function determines when the trajectory is inefficient or contains hallucination and should be stopped. Inefficient planning refers to trajectories that take too long without success. Hallucination is defined as encountering a sequence of consecutive identical actions that lead to the same observation in the environment.
# Self-reflection is created by showing two-shot examples to LLM and each example is a pair of (failed trajectory, ideal reflection for guiding future changes in the plan). Then reflections are added into the agent’s working memory, up to three, to be used as context for querying LLM.
#
# Memory stream: is a long-term memory module (external database) that records a comprehensive list of agents’ experience in natural language.
#
# Each element is an observation, an event directly provided by the agent.
# - Inter-agent communication can trigger new natural language statements.
#
#
# Retrieval model: surfaces the context to inform the agent’s behavior, according to relevance, recency and importance.
#
# Recency: recent events have higher scores
# Importance: distinguish mundane from core memories. Ask LM directly.
# Relevance: based on how related it is to the current situation / query.
#
#
# Reflection mechanism: synthesizes memories into higher level inferences over time and guides the agent’s future behavior. They are higher-level summaries of past events (<- note that this is a bit different from self-reflection above)
#
# Another quite distinct approach, LLM+P (Liu et al. 2023), involves relying on an external classical planner to do long-horizon planning. This approach utilizes the Planning Domain Definition Language (PDDL) as an intermediate interface to describe the planning problem. In this process, LLM (1) translates the problem into “Problem PDDL”, then (2) requests a classical planner to generate a PDDL plan based on an existing “Domain PDDL”, and finally (3) translates the PDDL plan back into natural language. Essentially, the planning step is outsourced to an external tool, assuming the availability of domain-specific PDDL and a suitable planner which is common in certain robotic setups but not in many other domains.
# Self-Reflection#
# Self-reflection is a vital aspect that allows autonomous agents to improve iteratively by refining past action decisions and correcting previous mistakes. It plays a crucial role in real-world tasks where trial and error are inevitable.
#
# Fig. 2.  Examples of reasoning trajectories for knowledge-intensive tasks (e.g. HotpotQA, FEVER) and decision-making tasks (e.g. AlfWorld Env, WebShop). (Image source: Yao et al. 2023).
# In both experiments on knowledge-intensive tasks and decision-making tasks, ReAct works better than the Act-only baseline where Thought: … step is removed.
# Reflexion (Shinn & Labash 2023) is a framework to equip agents with dynamic memory and self-reflection capabilities to improve reasoning skills. Reflexion has a standard RL setup, in which the reward model provides a simple binary reward and the action space follows the setup in ReAct where the task-specific action space is augmented with language to enable complex reasoning steps. After each action $a_t$, the agent computes a heuristic $h_t$ and optionally may decide to reset the environment to start a new trial depending on the self-reflection results.
# 'Self-reflection is a process that allows autonomous agents to improve by reviewing and learning from past actions and mistakes. It is particularly useful in real-world tasks where trial and error are common. In the context of the Reflexion framework, self-reflection is facilitated by providing examples of failed trajectories and ideal reflections to a language model, which then guides future planning.'

# %%
answer.content
# Out:
# 'Task decomposition in AI agents is done through methods like Chain of Thought (CoT), where the agent is prompted to "think step by step" to break down complex tasks into smaller, manageable ones. This process transforms large tasks into multiple simpler tasks, making them easier to handle and providing insight into the model\'s thinking process. The agent can then plan and execute these smaller tasks in a logical order.'

# %% [markdown]
# Query Analysis

# %%
total_documents = len(all_splits)

third = total_documents // 3

for i, doc in enumerate(all_splits):
    if i < third:
        doc.metadata["section"] = "beginning"
    elif i < 2 * third:
        doc.metadata["section"] = "middle"
    else:
        doc.metadata["section"] = "end"


all_splits[0].metadata
# Out:
# {'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/',
#  'start_index': 8,
#  'section': 'beginning'}

# %%
vector_store = InMemoryVectorStore(embeddings)
_ = vector_store.add_documents(all_splits)

# %% [markdown]
# Using LangGraph

# %%
from typing_extensions import TypedDict, List, Annotated, Literal
from langchain_core.documents import Document



# search
class Search(TypedDict):
    query: Annotated[str, ..., "Search query to run"]
    section: Annotated[Literal["beginning", "middle", "end"], ..., "Section of the document to search in"]

# state
class State(TypedDict):
    question: str
    context: List[Document]
    query: Search
    answer: str

# steps
def retrieve(state: State):
    retrieved_docs = vector_store.similarity_search(state["query"]["query"],
                                                    filter=lambda doc: doc.metadata.get("section") == state["query"]["section"])
    return {"context": retrieved_docs}

def generate(state: State):
    docs_content = "\n\n".join(doc.page_content for doc in state["context"])
    answer = llm.invoke(prompt.invoke({"question": state["question"], "context": docs_content}))
    return {"answer": answer.content}

def analyze_query(state: State):
    structured_llm = llm.with_structured_output(Search)
    query = structured_llm.invoke(state["question"])
    return {"query": query}


# control flow
from langgraph.graph import START, StateGraph

graph_builder = StateGraph(State).add_sequence([analyze_query,retrieve, generate])
graph_builder.add_edge(START, "analyze_query")
graph = graph_builder.compile()

# %%
for step in graph.stream({"question": "what is self reflection?"}, stream_mode="updates"):
    print(step)
# Out:
# {'analyze_query': {'query': {'query': 'self reflection', 'section': 'beginning'}}}
# {'retrieve': {'context': [Document(id='c5a72909-3486-456f-b89e-ba092cb4d46a', metadata={'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'start_index': 5221, 'section': 'beginning'}, page_content='Fig. 3. Illustration of the Reflexion framework. (Image source: Shinn & Labash, 2023)\nThe heuristic function determines when the trajectory is inefficient or contains hallucination and should be stopped. Inefficient planning refers to trajectories that take too long without success. Hallucination is defined as encountering a sequence of consecutive identical actions that lead to the same observation in the environment.\nSelf-reflection is created by showing two-shot examples to LLM and each example is a pair of (failed trajectory, ideal reflection for guiding future changes in the plan). Then reflections are added into the agent’s working memory, up to three, to be used as context for querying LLM.'), Document(id='c729866e-ad35-4cdd-9126-9ca7cd671ae7', metadata={'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'start_index': 4317, 'section': 'beginning'}, page_content='Fig. 2.  Examples of reasoning trajectories for knowledge-intensive tasks (e.g. HotpotQA, FEVER) and decision-making tasks (e.g. AlfWorld Env, WebShop). (Image source: Yao et al. 2023).\nIn both experiments on knowledge-intensive tasks and decision-making tasks, ReAct works better than the Act-only baseline where Thought: … step is removed.\nReflexion (Shinn & Labash 2023) is a framework to equip agents with dynamic memory and self-reflection capabilities to improve reasoning skills. Reflexion has a standard RL setup, in which the reward model provides a simple binary reward and the action space follows the setup in ReAct where the task-specific action space is augmented with language to enable complex reasoning steps. After each action $a_t$, the agent computes a heuristic $h_t$ and optionally may decide to reset the environment to start a new trial depending on the self-reflection results.'), Document(id='073dbc1c-b03f-4055-8c55-aa9848715482', metadata={'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'start_index': 2837, 'section': 'beginning'}, page_content='Another quite distinct approach, LLM+P (Liu et al. 2023), involves relying on an external classical planner to do long-horizon planning. This approach utilizes the Planning Domain Definition Language (PDDL) as an intermediate interface to describe the planning problem. In this process, LLM (1) translates the problem into “Problem PDDL”, then (2) requests a classical planner to generate a PDDL plan based on an existing “Domain PDDL”, and finally (3) translates the PDDL plan back into natural language. Essentially, the planning step is outsourced to an external tool, assuming the availability of domain-specific PDDL and a suitable planner which is common in certain robotic setups but not in many other domains.\nSelf-Reflection#\nSelf-reflection is a vital aspect that allows autonomous agents to improve iteratively by refining past action decisions and correcting previous mistakes. It plays a crucial role in real-world tasks where trial and error are inevitable.'), Document(id='5779fa12-c9e1-4082-ba25-1425db311692', metadata={'source': 'https://lilianweng.github.io/posts/2023-06-23-agent/', 'start_index': 6094, 'section': 'beginning'}, page_content='Chain of Hindsight (CoH; Liu et al. 2023) encourages the model to improve on its own outputs by explicitly presenting it with a sequence of past outputs, each annotated with feedback. Human feedback data is a collection of $D_h = \\{(x, y_i , r_i , z_i)\\}_{i=1}^n$, where $x$ is the prompt, each $y_i$ is a model completion, $r_i$ is the human rating of $y_i$, and $z_i$ is the corresponding human-provided hindsight feedback. Assume the feedback tuples are ranked by reward, $r_n \\geq r_{n-1} \\geq \\dots \\geq r_1$ The process is supervised fine-tuning where the data is a sequence in the form of $\\tau_h = (x, z_i, y_i ...
# {'generate': {'answer': 'Self-reflection is a process that allows autonomous agents to improve by reviewing and refining past actions and correcting mistakes. It is particularly important in tasks where trial and error are common. In the context of agents, self-reflection involves analyzing failed trajectories and using ideal reflections to guide future planning.'}}

# %% [markdown]
# Playground

# %%
import requests

response = requests.get(
    "https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r"
)

doc_files = response.json()

# %%
doc_files
# Out:
# [{'name': 'accessanalyzer_analyzer.html.markdown',
#   'path': 'website/docs/r/accessanalyzer_analyzer.html.markdown',
#   'sha': '2de4c28ab27e2b29c5a1d74329fb295a2ffc6790',
#   'size': 2869,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/accessanalyzer_analyzer.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/accessanalyzer_analyzer.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/2de4c28ab27e2b29c5a1d74329fb295a2ffc6790',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/accessanalyzer_analyzer.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/accessanalyzer_analyzer.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/2de4c28ab27e2b29c5a1d74329fb295a2ffc6790',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/accessanalyzer_analyzer.html.markdown'}},
#  {'name': 'accessanalyzer_archive_rule.html.markdown',
#   'path': 'website/docs/r/accessanalyzer_archive_rule.html.markdown',
#   'sha': '03651b6830f8825ed979efc76110eca5b5e6bf9f',
#   'size': 1949,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/accessanalyzer_archive_rule.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/accessanalyzer_archive_rule.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/03651b6830f8825ed979efc76110eca5b5e6bf9f',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/accessanalyzer_archive_rule.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/accessanalyzer_archive_rule.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/03651b6830f8825ed979efc76110eca5b5e6bf9f',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/accessanalyzer_archive_rule.html.markdown'}},
#  {'name': 'account_alternate_contact.html.markdown',
#   'path': 'website/docs/r/account_alternate_contact.html.markdown',
#   'sha': 'dcb8a23938809903686901843012eedda099a512',
#   'size': 2610,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/account_alternate_contact.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/account_alternate_contact.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/dcb8a23938809903686901843012eedda099a512',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/account_alternate_contact.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/account_alternate_contact.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/dcb8a23938809903686901843012eedda099a512',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/account_alternate_contact.html.markdown'}},
#  {'name': 'account_primary_contact.html.markdown',
#   'path': 'website/docs/r/account_primary_contact.html.markdown',
#   'sha': 'b45c0b9e1c0f8ffdea799f77a9c736267a79c335',
#   'size': 2692,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/account_primary_contact.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/account_primary_contact.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/b45c0b9e1c0f8ffdea799f77a9c736267a79c335',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/account_primary_contact.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/account_primary_contact.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/b45c0b9e1c0f8ffdea799f77a9c736267a79c335',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/account_primary_contact.html.markdown'}},
#  {'name': 'account_region.markdown',
#   'path': 'website/docs/r/account_region.markdown',
#   'sha': '24152c4e3920851fffa5dd805d70bc244a1eb19a',
#   'size': 1948,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/account_region.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/account_region.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/24152c4e3920851fffa5dd805d70bc244a1eb19a',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/account_region.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/account_region.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/24152c4e3920851fffa5dd805d70bc244a1eb19a',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/account_region.markdown'}},
#  {'name': 'acm_certificate.html.markdown',
#   'path': 'website/docs/r/acm_certificate.html.markdown',
#   'sha': '4355e6f9a1dab6a7f80e2d71fc9f07de8c0fe0ce',
#   'size': 10939,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acm_certificate.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acm_certificate.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/4355e6f9a1dab6a7f80e2d71fc9f07de8c0fe0ce',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/acm_certificate.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acm_certificate.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/4355e6f9a1dab6a7f80e2d71fc9f07de8c0fe0ce',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acm_certificate.html.markdown'}},
#  {'name': 'acm_certificate_validation.html.markdown',
#   'path': 'website/docs/r/acm_certificate_validation.html.markdown',
#   'sha': '7c4d0a4d66b89e0c2637cf61b0610c365294e8df',
#   'size': 4494,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acm_certificate_validation.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acm_certificate_validation.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/7c4d0a4d66b89e0c2637cf61b0610c365294e8df',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/acm_certificate_validation.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acm_certificate_validation.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/7c4d0a4d66b89e0c2637cf61b0610c365294e8df',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acm_certificate_validation.html.markdown'}},
#  {'name': 'acmpca_certificate.html.markdown',
#   'path': 'website/docs/r/acmpca_certificate.html.markdown',
#   'sha': '25779041acab70832b479df4501d7e24936accde',
#   'size': 3828,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_certificate.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_certificate.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/25779041acab70832b479df4501d7e24936accde',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/acmpca_certificate.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_certificate.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/25779041acab70832b479df4501d7e24936accde',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_certificate.html.markdown'}},
#  {'name': 'acmpca_certificate_authority.html.markdown',
#   'path': 'website/docs/r/acmpca_certificate_authority.html.markdown',
#   'sha': 'c2cdbda2379b9bf3e0adb83982d3186946cfd72e',
#   'size': 12247,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_certificate_authority.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_certificate_authority.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/c2cdbda2379b9bf3e0adb83982d3186946cfd72e',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/acmpca_certificate_authority.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_certificate_authority.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/c2cdbda2379b9bf3e0adb83982d3186946cfd72e',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_certificate_authority.html.markdown'}},
#  {'name': 'acmpca_certificate_authority_certificate.html.markdown',
#   'path': 'website/docs/r/acmpca_certificate_authority_certificate.html.markdown',
#   'sha': 'f71181c397b1e6c956065f8154623379034d52b9',
#   'size': 3778,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_certificate_authority_certificate.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_certificate_authority_certificate.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/f71181c397b1e6c956065f8154623379034d52b9',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/acmpca_certificate_authority_certificate.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_certificate_authority_certificate.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/f71181c397b1e6c956065f8154623379034d52b9',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_certificate_authority_certificate.html.markdown'}},
#  {'name': 'acmpca_permission.html.markdown',
#   'path': 'website/docs/r/acmpca_permission.html.markdown',
#   'sha': 'c985bd737386a5264d0a2c42a74a7f774fa5b1b7',
#   'size': 1889,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_permission.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_permission.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/c985bd737386a5264d0a2c42a74a7f774fa5b1b7',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/acmpca_permission.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_permission.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/c985bd737386a5264d0a2c42a74a7f774fa5b1b7',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_permission.html.markdown'}},
#  {'name': 'acmpca_policy.html.markdown',
#   'path': 'website/docs/r/acmpca_policy.html.markdown',
#   'sha': 'd4731ccd77e30286360768854c31234366895709',
#   'size': 2442,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_policy.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_policy.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/d4731ccd77e30286360768854c31234366895709',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/acmpca_policy.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/acmpca_policy.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/d4731ccd77e30286360768854c31234366895709',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/acmpca_policy.html.markdown'}},
#  {'name': 'ami.html.markdown',
#   'path': 'website/docs/r/ami.html.markdown',
#   'sha': '569206f4300c7462c56d97771a55c9014450838b',
#   'size': 7961,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/ami.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/ami.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/569206f4300c7462c56d97771a55c9014450838b',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/ami.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/ami.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/569206f4300c7462c56d97771a55c9014450838b',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/ami.html.markdown'}},
#  {'name': 'ami_copy.html.markdown',
#   'path': 'website/docs/r/ami_copy.html.markdown',
#   'sha': '64af45fcca767b91dd78d710c417909c9497ff62',
#   'size': 2883,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/ami_copy.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/ami_copy.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/64af45fcca767b91dd78d710c417909c9497ff62',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/ami_copy.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/ami_copy.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/64af45fcca767b91dd78d710c417909c9497ff62',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/ami_copy.html.markdown'}},
#  {'name': 'ami_from_instance.html.markdown',
#   'path': 'website/docs/r/ami_from_instance.html.markdown',
#   'sha': '9ea4db6454e754b7bdfcd35d1af61763c76e74bd',
#   'size': 2785,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/ami_from_instance.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/ami_from_instance.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/9ea4db6454e754b7bdfcd35d1af61763c76e74bd',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/ami_from_instance.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/ami_from_instance.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/9ea4db6454e754b7bdfcd35d1af61763c76e74bd',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/ami_from_instance.html.markdown'}},
#  {'name': 'ami_launch_permission.html.markdown',
#   'path': 'website/docs/r/ami_launch_permission.html.markdown',
#   'sha': 'b2a8e002e8fd9fa0cbc8e3610a690f68cd2e9b65',
#   'size': 2044,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/ami_launch_permission.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/ami_launch_permission.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/b2a8e002e8fd9fa0cbc8e3610a690f68cd2e9b65',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/ami_launch_permission.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/ami_launch_permission.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/b2a8e002e8fd9fa0cbc8e3610a690f68cd2e9b65',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/ami_launch_permission.html.markdown'}},
#  {'name': 'amplify_app.html.markdown',
#   'path': 'website/docs/r/amplify_app.html.markdown',
#   'sha': '7ed27f9b4864f3b89de2c71cd98a656e92d99ee6',
#   'size': 10155,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_app.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_app.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/7ed27f9b4864f3b89de2c71cd98a656e92d99ee6',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/amplify_app.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_app.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/7ed27f9b4864f3b89de2c71cd98a656e92d99ee6',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_app.html.markdown'}},
#  {'name': 'amplify_backend_environment.html.markdown',
#   'path': 'website/docs/r/amplify_backend_environment.html.markdown',
#   'sha': '3ce3305ff59f817ef76a0e226df3eb1b4d0f020e',
#   'size': 1708,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_backend_environment.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_backend_environment.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/3ce3305ff59f817ef76a0e226df3eb1b4d0f020e',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/amplify_backend_environment.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_backend_environment.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/3ce3305ff59f817ef76a0e226df3eb1b4d0f020e',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_backend_environment.html.markdown'}},
#  {'name': 'amplify_branch.html.markdown',
#   'path': 'website/docs/r/amplify_branch.html.markdown',
#   'sha': '674dc66bdb2c7006910988e0a55a05c2c64abbfd',
#   'size': 6606,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_branch.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_branch.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/674dc66bdb2c7006910988e0a55a05c2c64abbfd',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/amplify_branch.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_branch.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/674dc66bdb2c7006910988e0a55a05c2c64abbfd',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_branch.html.markdown'}},
#  {'name': 'amplify_domain_association.html.markdown',
#   'path': 'website/docs/r/amplify_domain_association.html.markdown',
#   'sha': '9e35255b9c0a4e0938738aef5caddc975eec2d44',
#   'size': 3392,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_domain_association.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_domain_association.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/9e35255b9c0a4e0938738aef5caddc975eec2d44',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/amplify_domain_association.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_domain_association.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/9e35255b9c0a4e0938738aef5caddc975eec2d44',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_domain_association.html.markdown'}},
#  {'name': 'amplify_webhook.html.markdown',
#   'path': 'website/docs/r/amplify_webhook.html.markdown',
#   'sha': 'a49e5d72692133daaca54e4371d2c5bed89951fc',
#   'size': 1499,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_webhook.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_webhook.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/a49e5d72692133daaca54e4371d2c5bed89951fc',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/amplify_webhook.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/amplify_webhook.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/a49e5d72692133daaca54e4371d2c5bed89951fc',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/amplify_webhook.html.markdown'}},
#  {'name': 'api_gateway_account.html.markdown',
#   'path': 'website/docs/r/api_gateway_account.html.markdown',
#   'sha': '44996a8cf79a0ef52f887aedf1d0d9055d3aabe7',
#   'size': 3323,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_account.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_account.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/44996a8cf79a0ef52f887aedf1d0d9055d3aabe7',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_account.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_account.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/44996a8cf79a0ef52f887aedf1d0d9055d3aabe7',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_account.html.markdown'}},
#  {'name': 'api_gateway_api_key.html.markdown',
#   'path': 'website/docs/r/api_gateway_api_key.html.markdown',
#   'sha': 'cd2327b283cb13839adce8392ab171009d6d309a',
#   'size': 2410,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_api_key.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_api_key.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/cd2327b283cb13839adce8392ab171009d6d309a',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_api_key.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_api_key.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/cd2327b283cb13839adce8392ab171009d6d309a',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_api_key.html.markdown'}},
#  {'name': 'api_gateway_authorizer.html.markdown',
#   'path': 'website/docs/r/api_gateway_authorizer.html.markdown',
#   'sha': '914eb60ef62d6bdce6b34781926280d3c77ddf31',
#   'size': 4869,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_authorizer.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_authorizer.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/914eb60ef62d6bdce6b34781926280d3c77ddf31',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_authorizer.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_authorizer.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/914eb60ef62d6bdce6b34781926280d3c77ddf31',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_authorizer.html.markdown'}},
#  {'name': 'api_gateway_base_path_mapping.html.markdown',
#   'path': 'website/docs/r/api_gateway_base_path_mapping.html.markdown',
#   'sha': '665f5b4b81d43f89ae966a7c781d615386be9ce0',
#   'size': 3681,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_base_path_mapping.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_base_path_mapping.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/665f5b4b81d43f89ae966a7c781d615386be9ce0',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_base_path_mapping.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_base_path_mapping.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/665f5b4b81d43f89ae966a7c781d615386be9ce0',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_base_path_mapping.html.markdown'}},
#  {'name': 'api_gateway_client_certificate.html.markdown',
#   'path': 'website/docs/r/api_gateway_client_certificate.html.markdown',
#   'sha': '04103e7167953f227b4355f1ac57ddde572044cc',
#   'size': 1922,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_client_certificate.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_client_certificate.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/04103e7167953f227b4355f1ac57ddde572044cc',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_client_certificate.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_client_certificate.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/04103e7167953f227b4355f1ac57ddde572044cc',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_client_certificate.html.markdown'}},
#  {'name': 'api_gateway_deployment.html.markdown',
#   'path': 'website/docs/r/api_gateway_deployment.html.markdown',
#   'sha': 'e75e98fee02a0438e912955ac1805b400a02bc23',
#   'size': 9531,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_deployment.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_deployment.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/e75e98fee02a0438e912955ac1805b400a02bc23',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_deployment.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_deployment.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/e75e98fee02a0438e912955ac1805b400a02bc23',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_deployment.html.markdown'}},
#  {'name': 'api_gateway_documentation_part.html.markdown',
#   'path': 'website/docs/r/api_gateway_documentation_part.html.markdown',
#   'sha': 'a597911a8bfc5d821e5ddb895edb20888b7864ab',
#   'size': 2639,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_documentation_part.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_documentation_part.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/a597911a8bfc5d821e5ddb895edb20888b7864ab',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_documentation_part.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_documentation_part.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/a597911a8bfc5d821e5ddb895edb20888b7864ab',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_documentation_part.html.markdown'}},
#  {'name': 'api_gateway_documentation_version.html.markdown',
#   'path': 'website/docs/r/api_gateway_documentation_version.html.markdown',
#   'sha': '7616105133b6118fe1678b80a95162c7829c5398',
#   'size': 1810,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_documentation_version.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_documentation_version.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/7616105133b6118fe1678b80a95162c7829c5398',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_documentation_version.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_documentation_version.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/7616105133b6118fe1678b80a95162c7829c5398',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_documentation_version.html.markdown'}},
#  {'name': 'api_gateway_domain_name.html.markdown',
#   'path': 'website/docs/r/api_gateway_domain_name.html.markdown',
#   'sha': '7f318dc3152ccbe0789f424f129d7cae6779f53c',
#   'size': 12919,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_domain_name.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_domain_name.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/7f318dc3152ccbe0789f424f129d7cae6779f53c',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_domain_name.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_domain_name.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/7f318dc3152ccbe0789f424f129d7cae6779f53c',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_domain_name.html.markdown'}},
#  {'name': 'api_gateway_domain_name_access_association.html.markdown',
#   'path': 'website/docs/r/api_gateway_domain_name_access_association.html.markdown',
#   'sha': '08286e9510a70d3597555da0c0a6acef86326e0f',
#   'size': 2782,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_domain_name_access_association.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_domain_name_access_association.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/08286e9510a70d3597555da0c0a6acef86326e0f',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_domain_name_access_association.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_domain_name_access_association.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/08286e9510a70d3597555da0c0a6acef86326e0f',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_domain_name_access_association.html.markdown'}},
#  {'name': 'api_gateway_gateway_response.html.markdown',
#   'path': 'website/docs/r/api_gateway_gateway_response.html.markdown',
#   'sha': '0516bfbc759feac3cd631a559c979c50ea62bca9',
#   'size': 1873,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_gateway_response.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_gateway_response.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/0516bfbc759feac3cd631a559c979c50ea62bca9',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_gateway_response.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_gateway_response.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/0516bfbc759feac3cd631a559c979c50ea62bca9',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_gateway_response.html.markdown'}},
#  {'name': 'api_gateway_integration.html.markdown',
#   'path': 'website/docs/r/api_gateway_integration.html.markdown',
#   'sha': '2a9885812624fccf85eaaa3cbdd62de01e4ea6b5',
#   'size': 11066,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_integration.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_integration.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/2a9885812624fccf85eaaa3cbdd62de01e4ea6b5',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_integration.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_integration.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/2a9885812624fccf85eaaa3cbdd62de01e4ea6b5',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_integration.html.markdown'}},
#  {'name': 'api_gateway_integration_response.html.markdown',
#   'path': 'website/docs/r/api_gateway_integration_response.html.markdown',
#   'sha': 'be7cd055ecfc2b72d62439a1195b425d70709efe',
#   'size': 4246,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_integration_response.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_integration_response.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/be7cd055ecfc2b72d62439a1195b425d70709efe',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_integration_response.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_integration_response.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/be7cd055ecfc2b72d62439a1195b425d70709efe',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_integration_response.html.markdown'}},
#  {'name': 'api_gateway_method.html.markdown',
#   'path': 'website/docs/r/api_gateway_method.html.markdown',
#   'sha': '9cff6d0ea9f14cec37f9443b303428e2a849122f',
#   'size': 4219,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_method.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_method.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/9cff6d0ea9f14cec37f9443b303428e2a849122f',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_method.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_method.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/9cff6d0ea9f14cec37f9443b303428e2a849122f',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_method.html.markdown'}},
#  {'name': 'api_gateway_method_response.html.markdown',
#   'path': 'website/docs/r/api_gateway_method_response.html.markdown',
#   'sha': '02ac879004f20f78a48e2cd24a118203fa0a5864',
#   'size': 5703,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_method_response.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_method_response.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/02ac879004f20f78a48e2cd24a118203fa0a5864',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_method_response.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_method_response.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/02ac879004f20f78a48e2cd24a118203fa0a5864',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_method_response.html.markdown'}},
#  {'name': 'api_gateway_method_settings.html.markdown',
#   'path': 'website/docs/r/api_gateway_method_settings.html.markdown',
#   'sha': '4b49e794ba1d0dd9a2fa57db5dca1265be458818',
#   'size': 6768,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_method_settings.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_method_settings.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/4b49e794ba1d0dd9a2fa57db5dca1265be458818',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_method_settings.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_method_settings.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/4b49e794ba1d0dd9a2fa57db5dca1265be458818',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_method_settings.html.markdown'}},
#  {'name': 'api_gateway_model.html.markdown',
#   'path': 'website/docs/r/api_gateway_model.html.markdown',
#   'sha': '17e2403e1f655891cfcbe793ca809b4ded99d7b5',
#   'size': 1601,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_model.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_model.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/17e2403e1f655891cfcbe793ca809b4ded99d7b5',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_model.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_model.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/17e2403e1f655891cfcbe793ca809b4ded99d7b5',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_model.html.markdown'}},
#  {'name': 'api_gateway_request_validator.html.markdown',
#   'path': 'website/docs/r/api_gateway_request_validator.html.markdown',
#   'sha': '0c869818cda91a899d6e0d1efa2d32dbc71e5b1d',
#   'size': 1644,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_request_validator.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_request_validator.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/0c869818cda91a899d6e0d1efa2d32dbc71e5b1d',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_request_validator.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_request_validator.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/0c869818cda91a899d6e0d1efa2d32dbc71e5b1d',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_request_validator.html.markdown'}},
#  {'name': 'api_gateway_resource.html.markdown',
#   'path': 'website/docs/r/api_gateway_resource.html.markdown',
#   'sha': '34602ba1ce7d6403a10eefd33a98e5865a5bc07d',
#   'size': 1586,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_resource.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_resource.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/34602ba1ce7d6403a10eefd33a98e5865a5bc07d',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_resource.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_resource.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/34602ba1ce7d6403a10eefd33a98e5865a5bc07d',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_resource.html.markdown'}},
#  {'name': 'api_gateway_rest_api.html.markdown',
#   'path': 'website/docs/r/api_gateway_rest_api.html.markdown',
#   'sha': '320a2707d4e84b74353fdedef89c7f6838006db5',
#   'size': 16736,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_rest_api.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_rest_api.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/320a2707d4e84b74353fdedef89c7f6838006db5',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/api_gateway_rest_api.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/api_gateway_rest_api.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/320a2707d4e84b74353fdedef89c7f6838006db5',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/api_gateway_rest_api.html.markdown'}},
#  {'name': 'api_gateway_rest_api_policy.html.markdown',
#   'path': 'website/docs/r/api_gateway_rest_api_policy.html.markdown',
#   'sha': 'ec37bb79b4a585cc510d063dc07b4e590a3722e8',
#   'size': 2165,
# ...
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_apns_channel.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_apns_channel.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/41e82ef8ceadf9c31576163c5ac3082751e65a78',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_apns_channel.html.markdown'}},
#  {'name': 'pinpoint_apns_sandbox_channel.html.markdown',
#   'path': 'website/docs/r/pinpoint_apns_sandbox_channel.html.markdown',
#   'sha': 'ae208f993b33ed9e90f72b7bc6c095ca979539df',
#   'size': 2986,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_apns_sandbox_channel.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_apns_sandbox_channel.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/ae208f993b33ed9e90f72b7bc6c095ca979539df',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_apns_sandbox_channel.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_apns_sandbox_channel.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/ae208f993b33ed9e90f72b7bc6c095ca979539df',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_apns_sandbox_channel.html.markdown'}},
#  {'name': 'pinpoint_apns_voip_channel.html.markdown',
#   'path': 'website/docs/r/pinpoint_apns_voip_channel.html.markdown',
#   'sha': 'b774ae74d51e6c7a8c103116149e655651c26bdb',
#   'size': 2942,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_apns_voip_channel.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_apns_voip_channel.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/b774ae74d51e6c7a8c103116149e655651c26bdb',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_apns_voip_channel.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_apns_voip_channel.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/b774ae74d51e6c7a8c103116149e655651c26bdb',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_apns_voip_channel.html.markdown'}},
#  {'name': 'pinpoint_apns_voip_sandbox_channel.html.markdown',
#   'path': 'website/docs/r/pinpoint_apns_voip_sandbox_channel.html.markdown',
#   'sha': '5205ff2659ca013366f0836cba332cc2ba1700e7',
#   'size': 3038,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_apns_voip_sandbox_channel.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_apns_voip_sandbox_channel.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/5205ff2659ca013366f0836cba332cc2ba1700e7',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_apns_voip_sandbox_channel.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_apns_voip_sandbox_channel.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/5205ff2659ca013366f0836cba332cc2ba1700e7',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_apns_voip_sandbox_channel.html.markdown'}},
#  {'name': 'pinpoint_app.html.markdown',
#   'path': 'website/docs/r/pinpoint_app.html.markdown',
#   'sha': '965ff3fb9de761110b4ae9a14bcf45f4b993b3b2',
#   'size': 3704,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_app.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_app.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/965ff3fb9de761110b4ae9a14bcf45f4b993b3b2',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_app.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_app.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/965ff3fb9de761110b4ae9a14bcf45f4b993b3b2',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_app.html.markdown'}},
#  {'name': 'pinpoint_baidu_channel.html.markdown',
#   'path': 'website/docs/r/pinpoint_baidu_channel.html.markdown',
#   'sha': 'e30e4092c7780c4900c8222fbb67ba278f223a31',
#   'size': 1574,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_baidu_channel.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_baidu_channel.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/e30e4092c7780c4900c8222fbb67ba278f223a31',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_baidu_channel.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_baidu_channel.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/e30e4092c7780c4900c8222fbb67ba278f223a31',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_baidu_channel.html.markdown'}},
#  {'name': 'pinpoint_email_channel.html.markdown',
#   'path': 'website/docs/r/pinpoint_email_channel.html.markdown',
#   'sha': '00dc825d36d80553c7ffcbda098c703106ab636b',
#   'size': 2882,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_email_channel.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_email_channel.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/00dc825d36d80553c7ffcbda098c703106ab636b',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_email_channel.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_email_channel.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/00dc825d36d80553c7ffcbda098c703106ab636b',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_email_channel.html.markdown'}},
#  {'name': 'pinpoint_email_template.markdown',
#   'path': 'website/docs/r/pinpoint_email_template.markdown',
#   'sha': '9294aab4b9cc20014af3e38f1abe7a77cbc8e83c',
#   'size': 4090,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_email_template.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_email_template.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/9294aab4b9cc20014af3e38f1abe7a77cbc8e83c',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_email_template.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_email_template.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/9294aab4b9cc20014af3e38f1abe7a77cbc8e83c',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_email_template.markdown'}},
#  {'name': 'pinpoint_event_stream.html.markdown',
#   'path': 'website/docs/r/pinpoint_event_stream.html.markdown',
#   'sha': 'a434ebfa7b2a6d3c2f02f89ee01a3747391b237d',
#   'size': 2352,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_event_stream.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_event_stream.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/a434ebfa7b2a6d3c2f02f89ee01a3747391b237d',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_event_stream.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_event_stream.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/a434ebfa7b2a6d3c2f02f89ee01a3747391b237d',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_event_stream.html.markdown'}},
#  {'name': 'pinpoint_gcm_channel.html.markdown',
#   'path': 'website/docs/r/pinpoint_gcm_channel.html.markdown',
#   'sha': '24c043c5e97dac79d79a85d0105b4ebf2a89f04b',
#   'size': 1791,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_gcm_channel.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_gcm_channel.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/24c043c5e97dac79d79a85d0105b4ebf2a89f04b',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_gcm_channel.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_gcm_channel.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/24c043c5e97dac79d79a85d0105b4ebf2a89f04b',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_gcm_channel.html.markdown'}},
#  {'name': 'pinpoint_sms_channel.html.markdown',
#   'path': 'website/docs/r/pinpoint_sms_channel.html.markdown',
#   'sha': '284d72aa3d3d371e8458ce7c3044726433cef3fc',
#   'size': 1647,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_sms_channel.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_sms_channel.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/284d72aa3d3d371e8458ce7c3044726433cef3fc',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpoint_sms_channel.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpoint_sms_channel.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/284d72aa3d3d371e8458ce7c3044726433cef3fc',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpoint_sms_channel.html.markdown'}},
#  {'name': 'pinpointsmsvoicev2_configuration_set.html.markdown',
#   'path': 'website/docs/r/pinpointsmsvoicev2_configuration_set.html.markdown',
#   'sha': '546d244a6e478ad25d9b8316a9c185802f7820bd',
#   'size': 2056,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpointsmsvoicev2_configuration_set.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpointsmsvoicev2_configuration_set.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/546d244a6e478ad25d9b8316a9c185802f7820bd',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpointsmsvoicev2_configuration_set.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpointsmsvoicev2_configuration_set.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/546d244a6e478ad25d9b8316a9c185802f7820bd',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpointsmsvoicev2_configuration_set.html.markdown'}},
#  {'name': 'pinpointsmsvoicev2_opt_out_list.html.markdown',
#   'path': 'website/docs/r/pinpointsmsvoicev2_opt_out_list.html.markdown',
#   'sha': '49b1acccc8bf37b1d56cc37247003e9ef9ff174b',
#   'size': 1698,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpointsmsvoicev2_opt_out_list.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpointsmsvoicev2_opt_out_list.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/49b1acccc8bf37b1d56cc37247003e9ef9ff174b',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpointsmsvoicev2_opt_out_list.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpointsmsvoicev2_opt_out_list.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/49b1acccc8bf37b1d56cc37247003e9ef9ff174b',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpointsmsvoicev2_opt_out_list.html.markdown'}},
#  {'name': 'pinpointsmsvoicev2_phone_number.html.markdown',
#   'path': 'website/docs/r/pinpointsmsvoicev2_phone_number.html.markdown',
#   'sha': '256a1b4bde45a8ffb6ece99a9fe6c671dfd90349',
#   'size': 3330,
#   'url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpointsmsvoicev2_phone_number.html.markdown?ref=main',
#   'html_url': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpointsmsvoicev2_phone_number.html.markdown',
#   'git_url': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/256a1b4bde45a8ffb6ece99a9fe6c671dfd90349',
#   'download_url': 'https://raw.githubusercontent.com/hashicorp/terraform-provider-aws/main/website/docs/r/pinpointsmsvoicev2_phone_number.html.markdown',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/contents/website/docs/r/pinpointsmsvoicev2_phone_number.html.markdown?ref=main',
#    'git': 'https://api.github.com/repos/hashicorp/terraform-provider-aws/git/blobs/256a1b4bde45a8ffb6ece99a9fe6c671dfd90349',
#    'html': 'https://github.com/hashicorp/terraform-provider-aws/blob/main/website/docs/r/pinpointsmsvoicev2_phone_number.html.markdown'}}]

# %%
file = doc_files[0]
if file["name"].endswith(".markdown"):
    file_response = requests.get(file["download_url"])
    doc = file_response.text
    print(doc)
# Out:
# ---
# subcategory: "IAM Access Analyzer"
# layout: "aws"
# page_title: "AWS: aws_accessanalyzer_analyzer"
# description: |-
#   Manages an Access Analyzer Analyzer
# ---
#
# # Resource: aws_accessanalyzer_analyzer
#
# Manages an Access Analyzer Analyzer. More information can be found in the [Access Analyzer User Guide](https://docs.aws.amazon.com/IAM/latest/UserGuide/what-is-access-analyzer.html).
#
# ## Example Usage
#
# ### Account Analyzer
#
# ```terraform
# resource "aws_accessanalyzer_analyzer" "example" {
#   analyzer_name = "example"
# }
# ```
#
# ### Organization Analyzer
#
# ```terraform
# resource "aws_organizations_organization" "example" {
#   aws_service_access_principals = ["access-analyzer.amazonaws.com"]
# }
#
# resource "aws_accessanalyzer_analyzer" "example" {
#   depends_on = [aws_organizations_organization.example]
#
#   analyzer_name = "example"
#   type          = "ORGANIZATION"
# }
# ```
#
# ## Argument Reference
#
# The following arguments are required:
#
# * `analyzer_name` - (Required) Name of the Analyzer.
#
# The following arguments are optional:
#
# * `configuration` - (Optional) A block that specifies the configuration of the analyzer. [Documented below](#configuration-argument-reference)
# * `tags` - (Optional) Key-value map of resource tags. If configured with a provider [`default_tags` configuration block](https://registry.terraform.io/providers/hashicorp/aws/latest/docs#default_tags-configuration-block) present, tags with matching keys will overwrite those defined at the provider-level.
# * `type` - (Optional) Type of Analyzer. Valid values are `ACCOUNT`, `ORGANIZATION`, `ACCOUNT_UNUSED_ACCESS `, `ORGANIZATION_UNUSED_ACCESS`. Defaults to `ACCOUNT`.
#
# ### `configuration` Argument Reference
#
# * `unused_access` - A block that specifies the configuration of an unused access analyzer for an AWS organization or account. [Documented below](#unused_access-argument-reference)
#
# ### `unused_access` Argument Reference
#
# * `unused_access_age` - The specified access age in days for which to generate findings for unused access.
#
# ## Attribute Reference
#
# This resource exports the following attributes in addition to the arguments above:
#
# * `arn` - ARN of the Analyzer.
# * `id` - Analyzer name.
# * `tags_all` - Map of tags assigned to the resource, including those inherited from the provider [`default_tags` configuration block](https://registry.terraform.io/providers/hashicorp/aws/latest/docs#default_tags-configuration-block).
#
# ## Import
#
# In Terraform v1.5.0 and later, use an [`import` block](https://developer.hashicorp.com/terraform/language/import) to import Access Analyzer Analyzers using the `analyzer_name`. For example:
#
# ```terraform
# import {
#   to = aws_accessanalyzer_analyzer.example
#   id = "example"
# }
# ```
#
# Using `terraform import`, import Access Analyzer Analyzers using the `analyzer_name`. For example:
#
# ```console
# % terraform import aws_accessanalyzer_analyzer.example example
# ```

# %%
import frontmatter

resource = frontmatter.loads(doc)
resource.metadata
# Out:
# {'subcategory': 'IAM Access Analyzer',
#  'layout': 'aws',
#  'page_title': 'AWS: aws_accessanalyzer_analyzer',
#  'description': 'Manages an Access Analyzer Analyzer'}

# %%
import re


chunks = re.split(r"(##\s+.+)", doc)

print(chunks)

results = []
for i in range(1, len(chunks), 2):
    header = chunks[i].strip()
    body = chunks[i+1].strip()
    results.append({"header": header, "body": body})
    print({"header": header, "body": body})
# Out:
# ['---\nsubcategory: "IAM Access Analyzer"\nlayout: "aws"\npage_title: "AWS: aws_accessanalyzer_analyzer"\ndescription: |-\n  Manages an Access Analyzer Analyzer\n---\n\n# Resource: aws_accessanalyzer_analyzer\n\nManages an Access Analyzer Analyzer. More information can be found in the [Access Analyzer User Guide](https://docs.aws.amazon.com/IAM/latest/UserGuide/what-is-access-analyzer.html).\n\n', '## Example Usage', '\n\n#', '## Account Analyzer', '\n\n```terraform\nresource "aws_accessanalyzer_analyzer" "example" {\n  analyzer_name = "example"\n}\n```\n\n#', '## Organization Analyzer', '\n\n```terraform\nresource "aws_organizations_organization" "example" {\n  aws_service_access_principals = ["access-analyzer.amazonaws.com"]\n}\n\nresource "aws_accessanalyzer_analyzer" "example" {\n  depends_on = [aws_organizations_organization.example]\n\n  analyzer_name = "example"\n  type          = "ORGANIZATION"\n}\n```\n\n', '## Argument Reference', '\n\nThe following arguments are required:\n\n* `analyzer_name` - (Required) Name of the Analyzer.\n\nThe following arguments are optional:\n\n* `configuration` - (Optional) A block that specifies the configuration of the analyzer. [Documented below](#configuration-argument-reference)\n* `tags` - (Optional) Key-value map of resource tags. If configured with a provider [`default_tags` configuration block](https://registry.terraform.io/providers/hashicorp/aws/latest/docs#default_tags-configuration-block) present, tags with matching keys will overwrite those defined at the provider-level.\n* `type` - (Optional) Type of Analyzer. Valid values are `ACCOUNT`, `ORGANIZATION`, `ACCOUNT_UNUSED_ACCESS `, `ORGANIZATION_UNUSED_ACCESS`. Defaults to `ACCOUNT`.\n\n#', '## `configuration` Argument Reference', '\n\n* `unused_access` - A block that specifies the configuration of an unused access analyzer for an AWS organization or account. [Documented below](#unused_access-argument-reference)\n\n#', '## `unused_access` Argument Reference', '\n\n* `unused_access_age` - The specified access age in days for which to generate findings for unused access.\n\n', '## Attribute Reference', '\n\nThis resource exports the following attributes in addition to the arguments above:\n\n* `arn` - ARN of the Analyzer.\n* `id` - Analyzer name.\n* `tags_all` - Map of tags assigned to the resource, including those inherited from the provider [`default_tags` configuration block](https://registry.terraform.io/providers/hashicorp/aws/latest/docs#default_tags-configuration-block).\n\n', '## Import', '\n\nIn Terraform v1.5.0 and later, use an [`import` block](https://developer.hashicorp.com/terraform/language/import) to import Access Analyzer Analyzers using the `analyzer_name`. For example:\n\n```terraform\nimport {\n  to = aws_accessanalyzer_analyzer.example\n  id = "example"\n}\n```\n\nUsing `terraform import`, import Access Analyzer Analyzers using the `analyzer_name`. For example:\n\n```console\n% terraform import aws_accessanalyzer_analyzer.example example\n```\n']
# {'header': '## Example Usage', 'body': '#'}
# {'header': '## Account Analyzer', 'body': '```terraform\nresource "aws_accessanalyzer_analyzer" "example" {\n  analyzer_name = "example"\n}\n```\n\n#'}
# {'header': '## Organization Analyzer', 'body': '```terraform\nresource "aws_organizations_organization" "example" {\n  aws_service_access_principals = ["access-analyzer.amazonaws.com"]\n}\n\nresource "aws_accessanalyzer_analyzer" "example" {\n  depends_on = [aws_organizations_organization.example]\n\n  analyzer_name = "example"\n  type          = "ORGANIZATION"\n}\n```'}
# {'header': '## Argument Reference', 'body': 'The following arguments are required:\n\n* `analyzer_name` - (Required) Name of the Analyzer.\n\nThe following arguments are optional:\n\n* `configuration` - (Optional) A block that specifies the configuration of the analyzer. [Documented below](#configuration-argument-reference)\n* `tags` - (Optional) Key-value map of resource tags. If configured with a provider [`default_tags` configuration block](https://registry.terraform.io/providers/hashicorp/aws/latest/docs#default_tags-configuration-block) present, tags with matching keys will overwrite those defined at the provider-level.\n* `type` - (Optional) Type of Analyzer. Valid values are `ACCOUNT`, `ORGANIZATION`, `ACCOUNT_UNUSED_ACCESS `, `ORGANIZATION_UNUSED_ACCESS`. Defaults to `ACCOUNT`.\n\n#'}
# {'header': '## `configuration` Argument Reference', 'body': '* `unused_access` - A block that specifies the configuration of an unused access analyzer for an AWS organization or account. [Documented below](#unused_access-argument-reference)\n\n#'}
# {'header': '## `unused_access` Argument Reference', 'body': '* `unused_access_age` - The specified access age in days for which to generate findings for unused access.'}
# {'header': '## Attribute Reference', 'body': 'This resource exports the following attributes in addition to the arguments above:\n\n* `arn` - ARN of the Analyzer.\n* `id` - Analyzer name.\n* `tags_all` - Map of tags assigned to the resource, including those inherited from the provider [`default_tags` configuration block](https://registry.terraform.io/providers/hashicorp/aws/latest/docs#default_tags-configuration-block).'}
# {'header': '## Import', 'body': 'In Terraform v1.5.0 and later, use an [`import` block](https://developer.hashicorp.com/terraform/language/import) to import Access Analyzer Analyzers using the `analyzer_name`. For example:\n\n```terraform\nimport {\n  to = aws_accessanalyzer_analyzer.example\n  id = "example"\n}\n```\n\nUsing `terraform import`, import Access Analyzer Analyzers using the `analyzer_name`. For example:\n\n```console\n% terraform import aws_accessanalyzer_analyzer.example example\n```'}

# %%
metadata = dict(resource.metadata)

# Extract main content
main_content = resource.content

# Separate sections
sections = {}
current_section = "main"
sections[current_section] = []

for line in main_content.split('\n'):
        if line.startswith('## '):
            current_section = line.replace('## ', '').strip()
            sections[current_section] = []
        else:
            sections[current_section].append(line)

structured_content = {
        "title": metadata.get("page_title", ""),
        "description": metadata.get("description", ""),
        "resource_name": re.search(r'# Resource: (.*)', main_content).group(1) if re.search(r'# Resource: (.*)', main_content) else "",
        "frontmatter": metadata,
        "sections": {k: '\n'.join(v) for k, v in sections.items()},
        "full_content": main_content
    }

# for k,v in structured_content['sections'].items():
#     print(f"{k}:",v)  

print(structured_content['full_content'])
# Out:
# # Resource: aws_accessanalyzer_analyzer
#
# Manages an Access Analyzer Analyzer. More information can be found in the [Access Analyzer User Guide](https://docs.aws.amazon.com/IAM/latest/UserGuide/what-is-access-analyzer.html).
#
# ## Example Usage
#
# ### Account Analyzer
#
# ```terraform
# resource "aws_accessanalyzer_analyzer" "example" {
#   analyzer_name = "example"
# }
# ```
#
# ### Organization Analyzer
#
# ```terraform
# resource "aws_organizations_organization" "example" {
#   aws_service_access_principals = ["access-analyzer.amazonaws.com"]
# }
#
# resource "aws_accessanalyzer_analyzer" "example" {
#   depends_on = [aws_organizations_organization.example]
#
#   analyzer_name = "example"
#   type          = "ORGANIZATION"
# }
# ```
#
# ## Argument Reference
#
# The following arguments are required:
#
# * `analyzer_name` - (Required) Name of the Analyzer.
#
# The following arguments are optional:
#
# * `configuration` - (Optional) A block that specifies the configuration of the analyzer. [Documented below](#configuration-argument-reference)
# * `tags` - (Optional) Key-value map of resource tags. If configured with a provider [`default_tags` configuration block](https://registry.terraform.io/providers/hashicorp/aws/latest/docs#default_tags-configuration-block) present, tags with matching keys will overwrite those defined at the provider-level.
# * `type` - (Optional) Type of Analyzer. Valid values are `ACCOUNT`, `ORGANIZATION`, `ACCOUNT_UNUSED_ACCESS `, `ORGANIZATION_UNUSED_ACCESS`. Defaults to `ACCOUNT`.
#
# ### `configuration` Argument Reference
#
# * `unused_access` - A block that specifies the configuration of an unused access analyzer for an AWS organization or account. [Documented below](#unused_access-argument-reference)
#
# ### `unused_access` Argument Reference
#
# * `unused_access_age` - The specified access age in days for which to generate findings for unused access.
#
# ## Attribute Reference
#
# This resource exports the following attributes in addition to the arguments above:
#
# * `arn` - ARN of the Analyzer.
# * `id` - Analyzer name.
# * `tags_all` - Map of tags assigned to the resource, including those inherited from the provider [`default_tags` configuration block](https://registry.terraform.io/providers/hashicorp/aws/latest/docs#default_tags-configuration-block).
#
# ## Import
#
# In Terraform v1.5.0 and later, use an [`import` block](https://developer.hashicorp.com/terraform/language/import) to import Access Analyzer Analyzers using the `analyzer_name`. For example:
#
# ```terraform
# import {
#   to = aws_accessanalyzer_analyzer.example
#   id = "example"
# }
# ```
#
# Using `terraform import`, import Access Analyzer Analyzers using the `analyzer_name`. For example:
#
# ```console
# % terraform import aws_accessanalyzer_analyzer.example example
# ```

# %%
for section_name, content in structured_content.get("sections", {}).items():
    # Extract code blocks and surrounding text
    code_blocks = re.findall(r"```terraform\n(.*?)\n```", content, re.DOTALL)
    text = re.sub(r"```terraform\n(.*?)\n```", "", content, flags=re.DOTALL).strip()

print(code_blocks)
print(text)
# Out:
# ['import {\n  to = aws_accessanalyzer_analyzer.example\n  id = "example"\n}']
# In Terraform v1.5.0 and later, use an [`import` block](https://developer.hashicorp.com/terraform/language/import) to import Access Analyzer Analyzers using the `analyzer_name`. For example:
#
#
#
# Using `terraform import`, import Access Analyzer Analyzers using the `analyzer_name`. For example:
#
# ```console
# % terraform import aws_accessanalyzer_analyzer.example example
# ```
